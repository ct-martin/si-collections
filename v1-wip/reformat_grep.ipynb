# %%
# Search for Outdoor Sculpture in SI records; output subset
# !grep -i "outdoor sculpture" all_data.ndjson > osculpt_grep.ndjson

# %%
# Convert ndjson to json
# !echo "[" > osculpt_grep.json
# !head --lines=-1 osculpt_grep.ndjson | awk '{ print $0 "," }' >> osculpt_grep.json
# !tail --lines=1 osculpt_grep.ndjson >> osculpt_grep.json
# !echo "]" >> osculpt_grep.json

# %%
import ujson

# %%
# Pretty-print json
with open('osculpt_grep.json') as infile:
    parsed = ujson.load(infile)
    
    with open('osculpt_grep_pretty.json','w') as out:
        out.write(ujson.dumps(parsed, indent=4))
# Out:
# [
#     {
#         "id":"edanmdm-siris_sil_358324",
#         "version":"",
#         "unitCode":"SIL",
#         "linkedId":"0",
#         "type":"edanmdm",
#         "content":{
#             "descriptiveNonRepeating":{
#                 "record_ID":"siris_sil_358324",
#                 "online_media":{
#                     "mediaCount":1,
#                     "media":[
#                         {
#                             "thumbnail":"https:\/\/library.si.edu\/sites\/default\/files\/styles\/book_cover_small\/public\/books\/covers\/fairmountparkar00fair_cover.jpg",
#                             "usage":{
#                                 "access":"CC0"
#                             },
#                             "type":"Scanned books",
#                             "content":"https:\/\/doi.org\/10.5479\/sil.358324.39088005854393"
#                         }
#                     ]
#                 },
#                 "unit_code":"SIL",
# ...
